# %%
import pandas as pd 
import numpy as np

# %%
icar_cheating_weight_pt5_estimate = pd.read_csv("/share/ju/matt/street-flooding/runs/icar_cheating/simulated_False/ahl_True/20241019-1247/estimate_at_least_one_positive_image_by_area.csv")

icar_none_estimate = pd.read_csv("/share/ju/matt/street-flooding/runs/icar_none/simulated_False/ahl_True/20241019-1303/estimate_at_least_one_positive_image_by_area.csv")

# %%
icar_none_estimate
# Out:
#           tract_id  empirical_estimate  at_least_one_positive_image_by_area  \
# 0     3.606100e+10                 NaN                             0.000000
# 1     3.606100e+10            0.000000                             0.318541
# 2     3.606100e+10            0.002367                             1.000000
# 3     3.606100e+10            0.000000                             0.226953
# 4     3.606100e+10            0.000000                             0.486240
# ...            ...                 ...                                  ...
# 2322  3.608502e+10            0.000000                             0.119360
# 2323  3.608502e+10            0.004902                             0.359063
# 2324  3.608503e+10            0.000000                             0.585418
# 2325  3.600502e+10            0.000000                             0.289380
# 2326  3.600502e+10            0.008000                             0.276687
#
#       at_least_one_positive_image_by_area_CI_lower  \
# ...

# %%
# scatterplor of at_least_one_positive_image_by_area across the two runs, 
# colored by the difference between the two runs
import matplotlib.pyplot as plt

plt.scatter(icar_cheating_weight_pt5_estimate["at_least_one_positive_image_by_area"], icar_none_estimate["at_least_one_positive_image_by_area"], c = icar_cheating_weight_pt5_estimate["at_least_one_positive_image_by_area"] - icar_none_estimate["at_least_one_positive_image_by_area"], cmap = "coolwarm")

# axis labels 
plt.xlabel("icar_cheating_weight_pt5_estimate")
plt.ylabel("icar_none_estimate")

# colorbar 
plt.colorbar()
